# %%
import pandas as pd

# %%
df = pd.read_csv("tempdata_log.csv", sep=";")

# %%
df.head()
# Out:
#                          Time  Temp  Humidity
# 0  2017-05-07 09:27:26.091979  22.0      70.0
# 1  2017-05-07 10:27:26.645891  22.0      70.0
# 2  2017-05-07 11:27:27.281549  22.0      70.0
# 3  2017-05-07 12:27:53.226381  22.0      69.0
# 4  2017-05-07 13:27:53.852320  22.0      69.0

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
get_ipython().magic(u'matplotlib inline')

# %%
plt.hist((df["Temp"]),bins=20)
# Out:
# (array([ 23.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,  21.,
#           0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,  12.]),
#  array([ 20. ,  20.1,  20.2,  20.3,  20.4,  20.5,  20.6,  20.7,  20.8,
#          20.9,  21. ,  21.1,  21.2,  21.3,  21.4,  21.5,  21.6,  21.7,
#          21.8,  21.9,  22. ]),
#  <a list of 20 Patch objects>)

# %%
sns.distplot(df["Humidity"],bins=20, kde_kws={'color':'indianred','label':'KDE PLOT'},
             hist_kws={'color':'blue','label':"HISTOGRAM"})
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot(df["Humidity"],df["Temp"])
